# %%
import pprint
import pandas as pd
import numpy as np
import re
import time
import datetime

import math
import cmath
from collections import Counter

import hashlib

# %%
# Read the txt file

file_path = 'resources/day15_input_test.txt'

# Open the file and read its contents using readlines()
with open(file_path, 'r') as file:
    text = file.read()
print(text)
# Out:
# rn=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7

# %%
# Read the txt file

file_path = 'resources/day15_input.txt'

# Open the file and read its contents using readlines()
with open(file_path, 'r') as file:
    for line in file:
        line = line.strip().split(',')

    for each in line:
        print(each)

print(line)
# Out:
# sbckcf-
# svx-
# jh-
# hfx=2
# xnd-
# cx-
# zd=6
# hm-
# bgf-
# lkn-
# sgpz-
# mjgk=2
# zcq=1
# rjv=3
# kq-
# bhqn-
# hlz-
# nk-
# rzg-
# nj-
# dtv=4
# jqp=6
# sj=6
# df=7
# zb=5
# hvpnx-
# rd=9
# hzv=7
# nkk-
# dzkdph-
# jqp=6
# dtv-
# pff=4
# cx-
# sbt=3
# bxgklq=9
# kbj=5
# vf=5
# mznnc=2
# xt-
# rzx=3
# xt-
# sm-
# gc=1
# trx-
# jc=5
# fgb=4
# lc-
# cs=3
# vbn-
# pp=8
# ng=5
# tbb-
# rjtt=9
# nj=9
# vnfq=6
# zq-
# qcr=7
# zh=6
# sjv-
# pl=6
# ccr-
# hlfg-
# xmf=1
# tsmm=8
# ctsf=4
# gst=1
# pp-
# kck-
# rmm=5
# dzs-
# xt=7
# kcg=3
# tt-
# nr-
# rlsb=7
# sqdb-
# zjxhp=2
# bnc=2
# crn-
# fsfgj=9
# vdtv=8
# rx-
# lq-
# tgzqhz=9
# xp-
# hdvm=4
# zs=9
# xtx-
# kjm-
# mjgk=3
# qlj-
# pfffk=3
# bgr=6
# ffp-
# vgqks-
# lmn-
# fxf=8
# tlrdb-
# cbqn-
# bnnl=6
# cv=5
# nj=9
# xtx-
# cxdvn-
# tkn=3
# zfr=7
# qc=8
# fgbmr-
# bpkl-
# pp-
# nnkn-
# qdjqqj=2
# gbn=7
# tjvtx=7
# rzg=1
# gqp=1
# sldvr-
# lc=4
# ms=1
# pg-
# dz-
# vq-
# rz=6
# ld-
# fzrg=7
# cqc-
# pxrt-
# tbb=8
# rzx=5
# kqfx-
# ...

# %% [markdown]
# ## PART 1

# %%
# def ascii_to_hash(ascii_str):
#     # Encode the ASCII string to bytes
#     ascii_bytes = ascii_str.encode('utf-8')

#     # Calculate the hash using SHA-256 algorithm
#     hashed = hashlib.sha256(ascii_bytes)

#     # Get the hexadecimal representation of the hash
#     hash_value = hashed.hexdigest()

#     return hash_value

# # Example usage
# ascii_string = "Your ASCII string here"
# hash_result = ascii_to_hash(ascii_string)
# print(f"Hash value of '{ascii_string}': {hash_result}")

# %%
# line = 'rn=1'
# ascii_code = ord('H')
# print(f"The ASCII code of 'H' is {ascii_code}")

# %%
results = []

for each in line:
    curr_val = 0
    print(each)
    for char in each:
        remainder = 0
        print(char)
        curr_val += ord(char)
        print(ord(char))
        mul_val = curr_val*17
        # print(mul_val)
        remainder = mul_val % 256
        curr_val = remainder
        # print(remainder)
        # print(curr_val)
        print()
        
    print(f'Final {curr_val}')
    results.append(curr_val)
# Out:
# sbckcf-
# s
# 115
#
# b
# 98
#
# c
# 99
#
# k
# 107
#
# c
# 99
#
# f
# 102
#
# -
# 45
#
# Final 121
# svx-
# s
# 115
#
# v
# 118
#
# x
# 120
#
# -
# 45
#
# Final 62
# jh-
# j
# 106
#
# h
# 104
#
# -
# 45
#
# Final 175
# hfx=2
# h
# 104
#
# f
# 102
#
# x
# 120
#
# =
# 61
#
# 2
# 50
#
# Final 245
# xnd-
# x
# 120
#
# n
# 110
#
# d
# 100
#
# -
# 45
#
# Final 103
# cx-
# c
# 99
#
# x
# 120
#
# -
# 45
#
# Final 104
# zd=6
# z
# 122
#
# d
# 100
#
# =
# 61
#
# 6
# 54
#
# Final 145
# hm-
# h
# 104
#
# m
# 109
#
# -
# 45
#
# Final 242
# bgf-
# b
# 98
#
# g
# 103
#
# f
# 102
#
# -
# 45
#
# Final 188
# lkn-
# l
# 108
#
# k
# 107
#
# n
# 110
#
# -
# 45
#
# Final 18
# sgpz-
# s
# 115
#
# g
# 103
#
# p
# 112
#
# z
# 122
#
# -
# 45
#
# Final 177
# mjgk=2
# m
# 109
#
# j
# 106
#
# g
# 103
#
# k
# 107
#
# =
# 61
#
# 2
# 50
#
# Final 168
# zcq=1
# z
# 122
#
# c
# 99
#
# q
# 113
#
# =
# 61
#
# 1
# 49
#
# Final 124
# rjv=3
# r
# 114
#
# j
# 106
#
# v
# 118
#
# =
# 61
#
# 3
# 51
#
# Final 210
# kq-
# k
# ...

# %%
sum(results)
# Out:
# 514394
